# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
import requests
r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
response = r.text

response
# Out:
# '[{"id":232915418,"title":"（幫推）急尋失去的聲音😢","excerpt":"「牠不只是寵物，更是爸爸留下的寶物！」屏東市女飼主的灰鸚鵡「小乖」意外走失，從明正國中後門飛走後就沒再回家，讓家人相當焦急。老母親為了找回「老伴的聲音」，每天從清晨找到半夜，卻遲遲不見蹤跡，整日以淚洗","anonymousSchool":false,"anonymousDepartment":true,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2020-01-18T15:36:46.157Z","updatedAt":"2020-01-18T23:36:24.252Z","commentCount":63,"likeCount":6393,"withNickname":false,"tags":[],"topics":["鸚鵡","屏東"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","gender":"F","school":"樹德科技大學","replyTitle":null,"mediaMeta":[{"id":"bd05a443-2e52-46be-ba3d-61833a8c6d88","url":"https://megapx-assets.dcard.tw/images/35bbb470-431a-4b68-a8c9-96fe919b71a0/640.jpeg","normalizedUrl":"https://megapx-assets.dcard.tw/images/35bbb470-431a-4b68-a8c9-96fe919b71a0/640.jpeg","thumbnail":"https://megapx-assets.dcard.tw/images/35bbb470-431a-4b68-a8c9-96fe919b71a0/640.jpeg","type":"image/thumbnail","tags":["ANNOTATED"],"createdAt":"2020-01-18T15:36:46.157Z","updatedAt":"2020-01-18T23:36:24.252Z","width":383,"height":640},{"id":"bd05a443-2e52-46be-ba3d-61833a8c6d88","url":"https://megapx-assets.dcard.tw/images/35bbb470-431a-4b68-a8c9-96fe919b71a0/1280.jpeg","normalizedUrl":"https://megapx.dcard.tw/v1/images/35bbb470-431a-4b68-a8c9-96fe919b71a0","thumbnail":"https://megapx-assets.dcard.tw/images/35bbb470-431a-4b68-a8c9-96fe919b71a0/640.jpeg","type":"image/megapx","tags":["ANNOTATED"],"createdAt":"2020-01-18T15:36:46.157Z","updatedAt":"2020-01-18T23:36:24.252Z","width":1125,"height":1879}],"reactions":[{"id":"286f599c-f86a-4932-82f0-f5a06f1eca03","count":6234},{"id":"514c2569-fd53-4d9d-a415-bf0f88e7329f","count":139},{"id":"011ead16-9b83-4729-9fde-c588920c6c2d","count":14},{"id":"e8e6bc5d-41b0-4129-b134-97507523d7ff","count":3},{"id":"4b018f48-e184-445f-adf1-fc8e04ba09b9","count":2},{"id":"aa0d425f-d530-4478-9a77-fe3aedc79eea","count":1}],"hidden":false,"customStyle":null,"isSuspiciousAccount":false,"layout":"classic","withImages":true,"withVideos":false,"media":[{"url":"https://megapx-assets.dcard.tw/images/35bbb470-431a-4b68-a8c9-96fe919b71a0/1280.jpeg"}],"reportReasonText":"","postAvatar":""},{"id":232916761,"title":"決戰飲水機","excerpt":"事情是這樣的，我有一隻貓，乖巧懂事又貼心，而今年過年我待在外縣市打拼上班，所以過年我要跟這隻貓兩人世界，-，至於飲水機，我從好久之前就想買了，但礙於太貴一直沒下手，但今年過年一個人過想來點不一樣的，加","anonymousSchool":false,"anonymousDepartment":true,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2020-01-18T19:33:17.906Z","updatedAt":"2020-01-18T19:35:27.449Z","commentCount":32,"likeCount":549,"withNickname":false,"tags":[],"topics":["飲水機","貓","我的貓會笑"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","gender":"F","school":"國立澎湖科技大學","replyTitle":null,"mediaMeta":[{"id":"acae83e2-ca58-40a5-9a7c-3446262ce28a","url":"https://megapx-assets.dcard.tw/images/473374e6-2c8b-4f95-a417-6ccb905d1200/640.jpeg","normalizedUrl":"https://megapx-assets.dcard.tw/images/473374e6-2c8b-4f95-a417-6ccb905d1200/640.jpeg","thumbnail":"https://megapx-assets.dcard.tw/images/473374e6-2c8b-4f95-a417-6ccb905d1200/640.jpeg","type":"image/thumbnail","tags":["ANNOTATED"],"createdAt":"2020-01-18T19:33:17.906Z","updatedAt":"2020-01-18T19:35:27.449Z","width":640,"height":640},{"id":"acae83e2-ca58-40a5-9a7c-3446262ce28a","url":"https://megapx-assets.dcard.tw/images/473374e6-2c8b-4f95-a417-6ccb905d1200/1280.jpeg","normalizedUrl":"https://megapx.dcard.tw/v1/images/473374e6-2c8b-4f95-a417-6ccb905d1200","thumbnail":"https://megapx-assets.dcard.tw/images/473374e6-2c8b-4f95-a417-6ccb905d1200/640.jpeg","type":"image/megapx","tags":["ANNOTATED"],"createdAt":"2020-01-18T19:33:17.906Z","updatedAt":"2020-01-18T19:35:27.449Z","width":2000,"height":2000},{"id":"2a2293bf-119a-43f4-aca6-2b9b8dce7161","url":"https://megapx-assets.dcard.tw/images/b603ee73-ab81-4a92-a572-d7a7f319789a/1280.jpeg","normalizedUrl":"https://megapx.dcard.tw/v1/images/b603ee73-ab81-4a92-a572-d7a7f319789a","thumbnail":"https://megapx-assets.dcard.tw/images/b603ee73-ab81-4a92-a572-d7a7f31 ...

# %%
import json
import pandas as pd
df = pd.read_json(response)
print('每次回傳{}筆'.format(len(df)))
print('欄位數量{}'.format(len(df.columns)))
# Out:
# 每次回傳30筆
# 欄位數量33

# %%
df.head()
# Out:
#           id               title  \
# 0  232915418        （幫推）急尋失去的聲音😢
# 1  232916761               決戰飲水機
# 2  232917196          爸媽不準養寵物的原因
# 3  232916901           這是一隻叫本丸的🐶
# 4  232919319  我的Macbook螢幕被貓啃爛...
#
#                                              excerpt  anonymousSchool  \
# 0  「牠不只是寵物，更是爸爸留下的寶物！」屏東市女飼主的灰鸚鵡「小乖」意外走失，從明正國中後門飛...            False
# 1  事情是這樣的，我有一隻貓，乖巧懂事又貼心，而今年過年我待在外縣市打拼上班，所以過年我要跟這隻...            False
# 2  身邊好幾個這樣的案例，不管是同學同事朋友，一開始都很反對甚至會怕寵物的，理由各式各樣就是不想...            False
# 3        看到我手中零食的本丸，看到主人手上零食，毫不猶豫的搭了一隻爪在我手背上（這是被寵幸了？            False
# 4  我家的貓趁我睡覺的時候把桌上的筆電翻開大啃特啃，各位有養貓的引以為戒啊，花了我18000.....            False
#
#    anonymousDepartment  pinned                               forumId  replyId  \
# 0                 True   False  7ee21581-1307-4ba9-b9dc-82028bdcca49      NaN
# 1                 True   False  7ee21581-1307-4ba9-b9dc-82028bdcca49      NaN
# 2                 True   False  7ee21581-1307-4ba9-b9dc-82028bdcca49      NaN
# 3                 True   False  7ee21581-1307-4ba9-b9dc-82028bdcca49      NaN
# 4                 True   False  7ee21581-1307-4ba9-b9dc-82028bdcca49      NaN
#
#                   createdAt                 updatedAt  ...  hidden  \
# 0  2020-01-18T15:36:46.157Z  2020-01-18T23:36:24.252Z  ...   False
# 1  2020-01-18T19:33:17.906Z  2020-01-18T19:35:27.449Z  ...   False
# 2  2020-01-19T01:14:10.452Z  2020-01-19T01:15:41.727Z  ...   False
# 3  2020-01-18T20:42:39.601Z  2020-01-18T20:42:39.601Z  ...   False
# 4  2020-01-19T10:16:11.891Z  2020-01-19T10:16:11.891Z  ...   False
#
#    customStyle  isSuspiciousAccount   layout withImages withVideos  \
# 0          NaN                False  classic       True      False
# 1          NaN                False  classic       True       True
# 2          NaN                False  classic       True      False
# 3          NaN                False  classic       True      False
# 4          NaN                False  classic       True      False
#
#                                                media reportReasonText  \
# 0  [{'url': 'https://megapx-assets.dcard.tw/image...
# 1  [{'url': 'https://megapx-assets.dcard.tw/image...
# 2       [{'url': 'https://i.imgur.com/UAlTmn1.png'}]
# 3  [{'url': 'https://megapx-assets.dcard.tw/image...
# 4  [{'url': 'https://megapx-assets.dcard.tw/image...
#
#   postAvatar department
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 33 columns):
# id                     30 non-null int64
# title                  30 non-null object
# excerpt                30 non-null object
# anonymousSchool        30 non-null bool
# anonymousDepartment    30 non-null bool
# pinned                 30 non-null bool
# forumId                30 non-null object
# replyId                1 non-null float64
# createdAt              30 non-null object
# updatedAt              30 non-null object
# commentCount           30 non-null int64
# likeCount              30 non-null int64
# withNickname           30 non-null bool
# tags                   30 non-null object
# topics                 30 non-null object
# meta                   30 non-null object
# forumName              30 non-null object
# forumAlias             30 non-null object
# gender                 30 non-null object
# school                 30 non-null object
# replyTitle             1 non-null object
# mediaMeta              30 non-null object
# reactions              30 non-null object
# hidden                 30 non-null bool
# customStyle            0 non-null float64
# isSuspiciousAccount    30 non-null bool
# layout                 30 non-null object
# withImages             30 non-null bool
# withVideos             30 non-null bool
# media                  30 non-null object
# reportReasonText       30 non-null object
# postAvatar             30 non-null object
# department             6 non-null object
# dtypes: bool(8), float64(2), int64(3), object(20)
# memory usage: 6.2+ KB

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」

target = ['標題', '貼文時間', '留言人數', '按讚人數']

df_result = df[['title', 'createdAt', 'commentCount', 'likeCount']]

df_result.columns = target

df_result
# Out:
#                     標題                      貼文時間  留言人數  按讚人數
# 0         （幫推）急尋失去的聲音😢  2020-01-18T15:36:46.157Z    63  6393
# 1                決戰飲水機  2020-01-18T19:33:17.906Z    32   549
# 2           爸媽不準養寵物的原因  2020-01-19T01:14:10.452Z    13   243
# 3            這是一隻叫本丸的🐶  2020-01-18T20:42:39.601Z     7   125
# 4   我的Macbook螢幕被貓啃爛...  2020-01-19T10:16:11.891Z     8   108
# 5                 阿拉❤️  2020-01-18T15:42:54.692Z     6    92
# 6             狗狗走失了 #更  2020-01-19T13:08:02.743Z     8    52
# 7      狗狗真的來跟我姊道歉了（附影片  2020-01-19T16:17:00.553Z     4    45
# 8             求交出你家卯咪！  2020-01-18T16:55:17.977Z     3    41
# 9                 柴犬正男  2020-01-18T18:59:02.447Z     6    34
# 10     內心戲很多的一隻貓🐱 （圖多）  2020-01-19T07:56:37.517Z     0    31
# 11          心機小博美（圖多慎入  2020-01-19T07:01:41.959Z     2    31
# 12              兔兔過年報喜  2020-01-19T03:44:13.287Z     5    30
# 13                我很自責  2020-01-18T19:01:47.283Z     4    24
# 14            他好像真的很想吃  2020-01-19T12:08:29.050Z     1    19
# 15       同學 快把你家貓貓照交出來  2020-01-19T06:05:42.279Z     4    19
# 16          ⚠️遺失 台中尋愛犬  2020-01-18T16:06:21.237Z     0    18
# 17              受傷浪貓送養  2020-01-19T11:32:25.279Z     1    17
# 18          謝拉拉為什麼叫謝拉拉  2020-01-19T14:26:41.339Z     0    14
# 19          搞壞野貓🤣🤣❤️❤️  2020-01-18T17:40:27.083Z     2    14
# 20                  🐢🐢  2020-01-19T05:08:40.674Z     7    13
# 21              是想被檢舉嗎  2020-01-19T09:49:59.562Z     0    11
# 22               睡覺吐舌👅  2020-01-18T18:52:23.697Z     1    11
# 23                另類溫杯  2020-01-18T15:58:48.470Z     3    11
# 24           阿尼基首發，大家好  2020-01-19T11:21:20.797Z     0    10
# 25        狗狗尿在別人家牆壁怎處理  2020-01-19T01:09:17.001Z    10    10
# 26          不棄養>領養代替購買  2020-01-19T13:25:43.283Z     1     8
# 27                崩壞狗狗  2020-01-18T20:44:54.895Z     1     8
# 28             領養？代替購買  2020-01-18T14:54:21.532Z    26     8
# 29         同學，你的貓貓被通緝了  2020-01-19T16:53:29.089Z     0     6

# %%
import requests
r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=false')
response_non = r.text

import json
import pandas as pd
df_non = pd.read_json(response_non)
print('每次回傳{}筆'.format(len(df_non)))
print('欄位數量{}'.format(len(df_non.columns)))
# Out:
# 每次回傳30筆
# 欄位數量34

# %%
df_non_result = df_non[['title', 'createdAt', 'commentCount', 'likeCount']]

df_non_result.columns = target

df_non_result
# Out:
#                        標題                      貼文時間  留言人數  按讚人數
# 0                  同時養兩隻貓  2020-01-20T02:40:53.745Z     0     0
# 1      分享#貓咪插畫春聯 (ibon列印)  2020-01-20T02:07:40.899Z     1     2
# 2           現在是貓的時代！貓奴請進！  2020-01-19T23:07:14.543Z     5     4
# 3               有關貓咪生小孩之後  2020-01-19T19:47:01.159Z     2     1
# 4               長得像芝娃娃的浪浪  2020-01-19T18:20:27.169Z     0     3
# 5                請問基隆兔科診所  2020-01-19T17:52:11.523Z     0     1
# 6               高雄鳳山獸醫推薦～  2020-01-19T17:20:28.218Z     3     0
# 7          #問 長尾龜的嘴巴裂開了？！  2020-01-19T16:56:03.912Z     1     0
# 8             同學，你的貓貓被通緝了  2020-01-19T16:53:29.089Z     0     7
# 9                    🐰🐰飼料  2020-01-19T16:25:03.060Z     0     1
# 10               女友自製倉鼠餅乾  2020-01-19T16:19:40.146Z     1     6
# 11             貓咪 狂犬病疫苗施打  2020-01-19T16:19:03.206Z     6     0
# 12        狗狗真的來跟我姊道歉了（附影片  2020-01-19T16:17:00.553Z     4    51
# 13               想請問有沒有鯛民  2020-01-19T15:47:27.686Z     0     0
# 14             有推薦的鳳梨果乾嗎～  2020-01-19T15:41:29.832Z     2     1
# 15          下泌尿道症候群：泌尿道感染  2020-01-19T15:35:39.195Z     5     6
# 16           有人知道他為什麼會這樣嗎  2020-01-19T15:19:10.128Z     2     1
# 17                 這隻是哪位🦐  2020-01-19T14:39:04.131Z     2     1
# 18             謝拉拉為什麼叫謝拉拉  2020-01-19T14:26:41.339Z     0    14
# 19             不棄養>領養代替購買  2020-01-19T13:25:43.283Z     1     8
# 20               狗狗走失了 #更  2020-01-19T13:08:02.743Z     8    53
# 21                   旺美狗🐶  2020-01-19T12:43:39.053Z     1     4
# 22  請大家飼養毛孩，特別是貓咪務必要預防心絲蟲  2020-01-19T12:40:46.037Z     5     4
# 23               他好像真的很想吃  2020-01-19T12:08:29.050Z     1    20
# 24        鼠年春聯 （7-11自行列印）  2020-01-19T11:42:06.623Z     1     4
# 25                 受傷浪貓送養  2020-01-19T11:32:25.279Z     1    17
# 26              阿尼基首發，大家好  2020-01-19T11:21:20.797Z     0    10
# 27            餵完貓驅蟲要後大出絛蟲  2020-01-19T10:46:19.691Z     3     1
# 28          貓咪一直舔自己一直叫 #急  2020-01-19T10:40:09.471Z     5     1
# 29     我的Macbook螢幕被貓啃爛...  2020-01-19T10:16:11.891Z     8   125

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

print('熱門文章-平均留言人數:{}'.format(df_result['留言人數'].mean()))
print('熱門文章-平均按讚人數:{}'.format(df_result['按讚人數'].mean()))
print('非熱門文章-平均留言人數:{}'.format(df_non_result['留言人數'].mean()))
print('非熱門文章-平均按讚人數:{}'.format(df_non_result['按讚人數'].mean()))
# Out:
# 熱門文章-平均留言人數:7.266666666666667
# 熱門文章-平均按讚人數:266.5
# 非熱門文章-平均留言人數:2.2666666666666666
# 非熱門文章-平均按讚人數:11.533333333333333
